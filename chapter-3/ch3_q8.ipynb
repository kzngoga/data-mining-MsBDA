# %% [markdown]
# # Chapter 3 - Exercise 8
# Simple linear regression of `mpg` on `horsepower` using the `Auto` data set.

# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from ISLP import load_data
from ISLP.models import ModelSpec as MS, summarize

# %%
Auto = load_data('Auto')

# %% [markdown]
# **(a)** Fit the model with `sm.OLS()` and print the summary.

# %%
design = MS(['horsepower'])
X = design.fit_transform(Auto)
y = Auto['mpg']
results = sm.OLS(y, X).fit()
summarize(results)
# Out:
#                coef  std err       t  P>|t|
# intercept   39.9359    0.717  55.660    0.0
# horsepower  -0.1578    0.006 -24.489    0.0

# %% [markdown]
# There is a statistically significant relationship between `horsepower` and `mpg` (p ≈ 0). The negative coefficient shows the relationship is **negative** — mpg falls as horsepower rises. The R² below gives a sense of relationship strength.

# %%
results.rsquared
# Out:
# np.float64(0.6059482578894348)

# %% [markdown]
# Predicted `mpg` at `horsepower` = 98, with 95% confidence and prediction intervals.

# %%
new_df = pd.DataFrame({'horsepower': [98]})
newX = design.transform(new_df)
prediction = results.get_prediction(newX)
prediction.predicted_mean
# Out:
# array([24.46707715])

# %%
prediction.conf_int(alpha=0.05)
# Out:
# array([[23.97307896, 24.96107534]])

# %%
prediction.conf_int(obs=True, alpha=0.05)
# Out:
# array([[14.80939607, 34.12475823]])

# %% [markdown]
# **(b)** Plot `mpg` vs. `horsepower` with the least squares line.

# %%
def abline(ax, b, m, *args, **kwargs):
    "Add a line with slope m and intercept b to ax"
    xlim = ax.get_xlim()
    ylim = [m * xlim[0] + b, m * xlim[1] + b]
    ax.plot(xlim, ylim, *args, **kwargs)

# %%
ax = Auto.plot.scatter('horsepower', 'mpg')
abline(ax, results.params[0], results.params[1], 'r--', linewidth=3)
# Out:
# /tmp/ipykernel_680/2650452964.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   abline(ax, results.params[0], results.params[1], 'r--', linewidth=3)

# %% [markdown]
# **(c)** Diagnostic plots: residuals vs. fitted values, and leverage.

# %%
fig, ax = subplots(figsize=(8, 8))
ax.scatter(results.fittedvalues, results.resid)
ax.set_xlabel('Fitted value')
ax.set_ylabel('Residual')
ax.axhline(0, c='k', ls='--');

# %%
infl = results.get_influence()
fig, ax = subplots(figsize=(8, 8))
ax.scatter(np.arange(X.shape[0]), infl.hat_matrix_diag)
ax.set_xlabel('Index')
ax.set_ylabel('Leverage')
np.argmax(infl.hat_matrix_diag)
# Out:
# np.int64(115)

# %% [markdown]
# *Comment:* the residual plot shows a U-shape, which shows that the relationship between `horsepower` and `mpg` is not perfectly linear. The plot shows one or two points with higher leverage than the rest.
